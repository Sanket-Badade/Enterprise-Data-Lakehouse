-- %%
create schema if not exists streaming_catalog.silver_schema;

-- %%
CREATE TABLE IF NOT EXISTS streaming_catalog.silver_schema.orders
USING DELTA
LOCATION 'abfss://silver@mystreamingdb.dfs.core.windows.net/orders_data'

-- %%
select * from streaming_catalog.silver_schema.orders
